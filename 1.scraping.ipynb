# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
#import webbrowser

# %%
#Scraping
main_url = 'https://sgulyano.github.io/eval/'

html_url = ['02226005.html',
            '08846113.html',
            '19689783.html',
            '24363682.html',
            '24674969.html',
            '26742703.html',
            '33472214.html',
            '33561138.html',
            '33565025.html',
            '41557226.html',
            '43951333.html',
            '44868136.html',
            '45435188.html',
            '48033334.html',
            '51435303.html',
            '53231654.html',
            '60189297.html',
            '61116032.html',
            '66887754.html',
            '68346670.html',
            '71728345.html',
            '79550445.html',
            '83255004.html',
            '94026030.html',
            '95860997.html',
            '96905621.html']
eval_url = [main_url + url for url in html_url]
def get_table_data(item):
    data = []
    table_body = item.find("tbody")
    rows = table_body.find_all("tr")
    for row in rows :
        cols = row.find_all(["td","th"])
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele])
    return data

# Header + input  

i = int(input())
print(eval_url[i]) 
page = i
r = requests.get(eval_url[page])
soup = BeautifulSoup(r.content,"html.parser")
tables = soup.find_all("table")

head = pd.DataFrame(get_table_data(tables[0]))
subject = head.iloc[0,1]
semester = head.iloc[2,1] 
section = head.iloc[1,1]
n = head.iloc[5,1]
print(f"Subject : {subject} \nSec : {section}\nSemester : {semester} \nn:{n}\nระดับการประเมิน : 5 = ดีมาก 4 = ดี 3 = ปานกลาง 2 = พอใช้ 1 = ปรับปรุง 0 = N/A (ไม่สามารถประเมินได้)")


# Create Data Frame
df = pd.DataFrame(get_table_data(tables[2]))
df.dropna(how="all",inplace=True)
df.columns = df.iloc[1,:]
rows = [0,1]
df.drop(rows,axis=0,inplace=True)

# Change data type (object -> float)
for i in range(2,16):
   df.iloc[:,i] = pd.to_numeric(df.iloc[:,i])


# Set index to column "ที่"
df.set_index("ที่",inplace=True)

#เอา รวม และ รวมทั้งหมด ออก
df.drop(df[df.index.str.match("รวม")].index,inplace=True)

#Split section
df["topic"] = ""
sec = ""
c = 0
for i in df.index:
    if len(i)>3:
        sec = i 
        c += 1
    else:
        df.iloc[c,15] = sec
        c += 1
df.dropna(how= "any" , inplace= True)

#Change name ร้อยละ 
cols = []
count = 5
for column in df.columns:
    if column == 'ร้อยละ':
        cols.append(f'{count}(%)')
        count-=1
        continue
    cols.append(column)
df.columns = cols

df["section"] = section

#webbrowser.open(eval_url[page - 1])
df
# Out:
# https://sgulyano.github.io/eval/41557226.html
# Subject : YRY790
# Sec : 231863
# Semester : 2/2561
# n:7 (15.91%)
# ระดับการประเมิน : 5 = ดีมาก 4 = ดี 3 = ปานกลาง 2 = พอใช้ 1 = ปรับปรุง 0 = N/A (ไม่สามารถประเมินได้)
#                                               ข้อคำถาม    5   5(%)    4  \
# ที่
# 1                                     สอนอย่างเป็นระบบ  2.0  28.57  2.0
# 2                          สอนให้คิด วิเคราะห์ วิจารณ์  1.0  14.29  4.0
# 3    กระตุ้นบรรยากาศการเรียนการสอน มีวิธีสอนที่น่าส...  1.0  14.29  2.0
# 4    เปิดโอกาสให้แสดงความคิดเห็นและแลกเปลี่ยนประสบก...  2.0  28.57  4.0
# 5    มีการให้นำเสนองาน/มีการวัดผลโดยวิธีอื่นๆที่สะท...  1.0  14.29  3.0
# 6        ทำให้เห็นความสัมพันธ์กับวิชาอื่นที่เกี่ยวข้อง  2.0  28.57  3.0
# 7                        ใช้สื่อและอุปกรณ์ช่วยสอนได้ดี  2.0  28.57  3.0
# 8                  แนะนำแหล่งค้นคว้าข้อมูลเพิ่มเติมให้  2.0  28.57  5.0
# 1    ผู้สอนแจ้งวัตถุประสงค์และเนื้อหารายวิชาตามเค้า...  3.0  42.86  4.0
# 2        ผู้สอนแจ้งเกณฑ์และวิธีประเมินผลล่วงหน้าชัดเจน  5.0  71.43  2.0
# 3                       ผู้สอนเข้าสอนและเลิกสอนตรงเวลา  6.0  85.71  1.0
# 4                                  ผู้สอนมาสอนสม่ำเสมอ  5.0  71.43  2.0
# 5    ผู้สอนสอนเนื้อหาครบถ้วน และสอดคล้องตามเค้าโครง...  2.0  28.57  4.0
# 6                     ผู้สอนมีการเตรียมการสอนมาอย่างดี  3.0  42.86  3.0
# 7    ผู้สอนชี้แนะจุดมุ่งหมายประเด็นหรือข้อสรุปที่เป...  2.0  28.57  3.0
# 8    ผู้สอนแทรกเนื้อหาเกี่ยวกับคุณธรรมจริยธรรมในการ...  2.0  28.57  4.0
# 1    โสตทัศนูปกรณ์ช่วยสอนในห้องเรียน เช่น ไมโครโฟน ...  3.0  42.86  2.0
# 2    สภาพของห้องเรียนหรือห้องปฏิบัติการ เช่น แสง อุ...  2.0  28.57  1.0
# 3    จำนวนอุปกรณ์ในการเรียนการสอนเพียงพอ และเหมาะสม...  2.0  28.57  3.0
# 4    เจ้าหน้าที่อำนวยความสะดวกในการให้บริการในการเร...  3.0  42.86  2.0
#
#       4(%)    3   3(%)    2   2(%)    1  1(%)    0  0(%)  X-Bar    SD  \
# ที่
# 1    28.57  2.0  28.57  1.0  14.29  0.0   0.0  0.0   0.0   3.71  1.11
# 2    57.14  1.0  14.29  1.0  14.29  0.0   0.0  0.0   0.0   3.71  0.95
# 3    28.57  1.0  14.29  3.0  42.86  0.0   0.0  0.0   0.0   3.14  1.21
# 4    57.14  0.0   0.00  1.0  14.29  0.0   0.0  0.0   0.0   4.00  1.00
# 5    42.86  2.0  28.57  1.0  14.29  0.0   0.0  0.0   0.0   3.57  0.98
# 6    42.86  1.0  14.29  1.0  14.29  0.0   0.0  0.0   0.0   3.86  1.07
# 7    42.86  2.0  28.57  0.0   0.00  0.0   0.0  0.0   0.0   4.00  0.82
# 8    71.43  0.0   0.00  0.0   0.00  0.0   0.0  0.0   0.0   4.29  0.49
# 1    57.14  0.0   0.00  0.0   0.00  0.0   0.0  0.0   0.0   4.43  0.53
# 2    28.57  0.0   0.00  0.0   0.00  0.0   0.0  0.0   0.0   4.71  0.49
# 3    14.29  0.0   0.00  0.0   0.00  0.0   0.0  0.0   0.0   4.86  0.38
# 4    28.57  0.0   0.00  0.0   0.00  0.0   0.0  0.0   0.0   4.71  0.49
# 5    57.14  1.0  14.29  0.0   0.00  0.0   0.0  0.0   0.0   4.14  0.69
# 6    42.86  1.0  14.29  0.0   0.00  0.0   0.0  0.0   0.0   4.29  0.76
# 7    42.86  2.0  28.57  0.0   0.00  0.0   0.0  0.0   0.0   4.00  0.82
# 8    57.14  0.0   0.00  1.0  14.29  0.0   0.0  0.0   0.0   4.00  1.00
# 1    28.57  1.0  14.29  1.0  14.29  0.0   0.0  0.0   0.0   4.00  1.15
# 2    14.29  2.0  28.57  2.0  28.57  0.0   0.0  0.0   0.0   3.43  1.27
# 3    42.86  1.0  14.29  1.0  14.29  0.0   0.0  0.0   0.0   3.86  1.07
# 4    28.57  2.0  28.57  0.0   0.00  0.0   0.0  0.0   0.0   4.14  0.90
#
#                                                topic section
# ที่
# 1               ส่วนที่ 1 ข้อคำถามกลางของมหาวิทยาลัย  231863
# 2               ส่วนที่ 1 ข้อคำถามกลางของมหาวิทยาลัย  231863
# 3               ส่วนที่ 1 ข้อคำถามกลางของมหาวิทยาลัย  231863
# 4               ส่วนที่ 1 ข้อคำถามกลางของมหาวิทยาลัย  231863
# 5               ส่วนที่ 1 ข้อคำถามกลางของมหาวิทยาลัย  231863
# 6               ส่วนที่ 1 ข้อคำถามกลางของมหาวิทยาลัย  231863
# 7               ส่วนที่ 1 ข้อคำถามกลางของมหาวิทยาลัย  231863
# 8               ส่วนที่ 1 ข้อคำถามกลางของมหาวิทยาลัย  231863
# 1                  ส่วนที่ 2 ข้อคำถามของคณะ/หน่วยงาน  231863
# 2                  ส่วนที่ 2 ข้อคำถามของคณะ/หน่วยงาน  231863
# 3                  ส่วนที่ 2 ข้อคำถามของคณะ/หน่วยงาน  231863
# 4                  ส่วนที่ 2 ข้อคำถามของคณะ/หน่วยงาน  231863
# 5                  ส่วนที่ 2 ข้อคำถามของคณะ/หน่วยงาน  231863
# 6                  ส่วนที่ 2 ข้อคำถามของคณะ/หน่วยงาน  231863
# 7                  ส่วนที่ 2 ข้อคำถามของคณะ/หน่วยงาน  231863
# 8                  ส่วนที่ 2 ข้อคำถามของคณะ/หน่วยงาน  231863
# 1    ส่วนที่ 3 สภาพแวดล้อมและสิ่งสนับสนุนการเรียนรู้  231863
# 2    ส่วนที่ 3 สภาพแวดล้อมและสิ่งสนับสนุนการเรียนรู้  231863
# 3    ส่วนที่ 3 สภาพแวดล้อมและสิ่งสนับสนุนการเรียนรู้  231863
# 4    ส่วนที่ 3 สภาพแวดล้อมและสิ่งสนับสนุนการเรียนรู้  231863
